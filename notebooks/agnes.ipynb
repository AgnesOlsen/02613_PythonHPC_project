# %% [markdown]
# # Testing if Hpc works

# %% [markdown]
# testiung adding changes

# %% [markdown]
# test 123

# %%
import numpy as np

np.load("../stats/time_num_cores.npy")
# Out:
# array([[ 4.        , 84.06479645],
#        [ 6.        , 62.97789621],
#        [ 8.        , 59.18634915]])
