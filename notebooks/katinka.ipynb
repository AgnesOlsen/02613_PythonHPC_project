# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
times = np.load("../stats/dynamic_time_50.npy")

# %%
times
# Out:
# array([[  1.        , 555.05069351],
#        [  2.        , 329.56806517],
#        [  4.        , 217.74279833],
#        [  8.        , 138.1063695 ],
#        [ 16.        , 102.17395639]])

# %%
speedup = times.copy()
speedup[:,1] = times[0,1]/times[:,1]

# %%
speedup
# Out:
# array([[ 1.        ,  1.        ],
#        [ 2.        ,  1.68417621],
#        [ 4.        ,  2.5491116 ],
#        [ 8.        ,  4.01900865],
#        [16.        ,  5.43240874]])

# %%
plt.plot(speedup[:,0],speedup[:,1])
