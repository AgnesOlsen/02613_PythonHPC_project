# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
times = np.load("../stats/dynamic_time_20.npy")

# %%
speedup = times
speedup[:,1] = times[0,0]/times[:,1]

# %%
plt.plot(speedup[:,0],speedup[:,1])
